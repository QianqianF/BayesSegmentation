# %% [markdown]
# Mount google drive

# %%
# !cp -r /content/drive/MyDrive/BayesSegmentation .

# %%
# !cp -r BayesSegmentation/ /content/drive/MyDrive/

# %%
cd BayesSegmentation/
# Out:
# /content/BayesSegmentation

# %%
# %run setup.py develop
# Out:
# running develop
# running egg_info
# writing swag.egg-info/PKG-INFO
# writing dependency_links to swag.egg-info/dependency_links.txt
# writing requirements to swag.egg-info/requires.txt
# writing top-level names to swag.egg-info/top_level.txt
# reading manifest file 'swag.egg-info/SOURCES.txt'
# writing manifest file 'swag.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.7/dist-packages/swag.egg-link (link to .)
# Adding swag 0.0 to easy-install.pth file
#
# Installed /content/BayesSegmentation
# Processing dependencies for swag==0.0
# Searching for gpytorch>=0.1.0rc4
# Reading https://pypi.org/simple/gpytorch/
# ...
# Best match: gpytorch 1.4.0
# Processing gpytorch-1.4.0.tar.gz
# Writing /tmp/easy_install-wk1t_7bm/gpytorch-1.4.0/setup.cfg
# Running gpytorch-1.4.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-wk1t_7bm/gpytorch-1.4.0/egg-dist-tmp-4ne7gw1_
# zip_safe flag not set; analyzing archive contents...
# ...

# %%
# !pip install --upgrade git+https://github.com/cornellius-gp/gpytorch.git
# Out:
# ...
#   Cloning https://github.com/cornellius-gp/gpytorch.git to /tmp/pip-req-build-kdffdxnp
#   Running command git clone -q https://github.com/cornellius-gp/gpytorch.git /tmp/pip-req-build-kdffdxnp
# ...
#   Created wheel for gpytorch: filename=gpytorch-1.4.0-py2.py3-none-any.whl size=486653 sha256=ea0562708fe371d5b8bf3b65ed18d72defd78eb48fcd243729d7e486b7c3b9f3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q9i6zy21/wheels/52/ac/ca/6dc889cad19909fc1590b26613028a9c8df1a4baf9b7385002
# Successfully built gpytorch
# ERROR: swag 0.0 has requirement tqdm==4.26.0, but you'll have tqdm 4.41.1 which is incompatible.
# ...
#   Found existing installation: gpytorch 1.4.0
#     Uninstalling gpytorch-1.4.0:
#       Successfully uninstalled gpytorch-1.4.0
# ...

# %%
# %run experiments/train/run_swag.py --epochs=300 --dataset=CIFAR10 \
--save_freq=300 --model=PreResNet164 --lr_init=0.1 --wd=3e-4 --swa --swa_start=161 \
--swa_lr=0.01 --cov_mat --use_test --dir=checkpoints --data_path=dataset
# Out:
# Preparing directory checkpoints
# Using model PreResNet164
# Loading dataset CIFAR10 from dataset
# ...
# Extracting dataset/cifar10/cifar-10-python.tar.gz to dataset/cifar10
# You are going to run models on the test set. Are you sure?
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Preparing model
#
# SWAG training
# ----  --------  ---------  --------  ---------  --------  -------------  ------------  --------  -----------
#   ep        lr    tr_loss    tr_acc    te_loss    te_acc  swa_te_loss    swa_te_acc        time    mem_usage
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '1.8.0+cu101'
