# %%
# !cp -r /content/drive/MyDrive/BayesSegmentation .

# %%
# !cp -r BayesSegmentation/ /content/drive/MyDrive/

# %%
cd BayesSegmentation/
# Out:
# /content/BayesSegmentation

# %%
# !unzip dataset/nuclei/train.zip -d dataset/nuclei
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/nuclei/__MACOSX/train/5908488d940e846cc121c768758da9b1bd5b9922417e20c9101a4e254fa98af8/._masks
#   inflating: dataset/nuclei/__MACOSX/train/._5908488d940e846cc121c768758da9b1bd5b9922417e20c9101a4e254fa98af8
#    creating: dataset/nuclei/train/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6/
#    creating: dataset/nuclei/train/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6/images/
#   inflating: dataset/nuclei/train/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6/images/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6.png
#    creating: dataset/nuclei/__MACOSX/train/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6/
#    creating: dataset/nuclei/__MACOSX/train/f01a9742c43a69f087700a43893f713878e537bae8e44f76b957f09519601ad6/images/
# ...

# %%
# !unzip dataset/nuclei/val.zip -d dataset/nuclei

# %%
# !unzip dataset/nuclei/test.zip -d dataset/nuclei

# %%
# %run setup.py develop
# Out:
# running develop
# running egg_info
# writing swag.egg-info/PKG-INFO
# writing dependency_links to swag.egg-info/dependency_links.txt
# writing requirements to swag.egg-info/requires.txt
# writing top-level names to swag.egg-info/top_level.txt
# reading manifest file 'swag.egg-info/SOURCES.txt'
# writing manifest file 'swag.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.7/dist-packages/swag.egg-link (link to .)
# Adding swag 0.0 to easy-install.pth file
#
# Installed /content/BayesSegmentation
# Processing dependencies for swag==0.0
# Searching for gpytorch>=0.1.0rc4
# Reading https://pypi.org/simple/gpytorch/
# ...
# Best match: gpytorch 1.4.1
# Processing gpytorch-1.4.1-py2.py3-none-any.whl
# Installing gpytorch-1.4.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding gpytorch 1.4.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/gpytorch-1.4.1-py3.7.egg
# Searching for tqdm==4.26.0
# ...

# %%
# !pip install --upgrade git+https://github.com/cornellius-gp/gpytorch.git
# Out:
# ...
#   Cloning https://github.com/cornellius-gp/gpytorch.git to /tmp/pip-req-build-g58hr1g8
#   Running command git clone -q https://github.com/cornellius-gp/gpytorch.git /tmp/pip-req-build-g58hr1g8
# ...
#   Created wheel for gpytorch: filename=gpytorch-1.4.1-py2.py3-none-any.whl size=491510 sha256=ee3618b302929d867b20e8523dbaacba46bb8671f4bf642c1daf6bd0c894df47
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fv726skw/wheels/52/ac/ca/6dc889cad19909fc1590b26613028a9c8df1a4baf9b7385002
# Successfully built gpytorch
# ...

# %%
# %run experiments/segmentation/train.py --dataset Nuclei --data_path dataset/nuclei --model FCDenseNet67 \
--loss cross_entropy --optimizer SGD --lr_init 1e-2 --batch_size 4 --ft_start 750 --ft_batch_size 1 \
--epochs 1000 --swa --swa_start=850 --swa_lr=1e-3 --dir checkpoints
# Out:
# Preparing directory checkpoints
# Using model FCDenseNet67
# dataset/nuclei
# Beginning with cropped images
# Preparing model
# SWAG training
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/BayesSegmentation/experiments/segmentation/utils/training.py:27: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
#   nn.init.kaiming_uniform(m.weight)
# ...

# %%
mv dataset/nuclei/val/8f94a80b95a881d0efdec36affc915dca9609f4cba8134c4a91b219d418778aa dataset/nuclei/train/8f94a80b95a881d0efdec36affc915dca9609f4cba8134c4a91b219d418778aa

# %%
cat /usr/local/cuda/version.txt
# Out:
# CUDA Version 11.0.228

# %%
cat /usr/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 6
# #define CUDNN_PATCHLEVEL 5
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# !nvidia-smi
# Out:
# Fri Apr 30 09:00:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    32W / 250W |   1595MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip dataset/CamVid.zip
# Out:
# Archive:  dataset/CamVid.zip
#    creating: CamVid/
#    creating: CamVid/test/
#   inflating: CamVid/test/0001TP_009030.png
#    creating: __MACOSX/CamVid/
#    creating: __MACOSX/CamVid/test/
#   inflating: __MACOSX/CamVid/test/._0001TP_009030.png
#   inflating: CamVid/test/0001TP_009540.png
#   inflating: __MACOSX/CamVid/test/._0001TP_009540.png
#   inflating: CamVid/test/Seq05VD_f03270.png
#   inflating: __MACOSX/CamVid/test/._Seq05VD_f03270.png
#   inflating: CamVid/test/0001TP_009420.png
#   inflating: __MACOSX/CamVid/test/._0001TP_009420.png
#   inflating: CamVid/test/Seq05VD_f00180.png
#   inflating: __MACOSX/CamVid/test/._Seq05VD_f00180.png
#   inflating: CamVid/test/0001TP_009150.png
#   inflating: __MACOSX/CamVid/test/._0001TP_009150.png
#   inflating: CamVid/test/Seq05VD_f03660.png
#   inflating: __MACOSX/CamVid/test/._Seq05VD_f03660.png
#   inflating: CamVid/test/0001TP_009810.png
#   inflating: __MACOSX/CamVid/test/._0001TP_009810.png
# ...

# %%
# %run experiments/segmentation/train.py --dataset CamVid --data_path dataset/CamVid --model FCDenseNet67 \
--loss cross_entropy --optimizer SGD --lr_init 1e-2 --batch_size 4 --ft_start 750 --ft_batch_size 1 \
--epochs 1000 --swa --swa_start=850 --swa_lr=1e-3 --dir checkpoints
# Out:
# Preparing directory checkpoints
# Using model FCDenseNet67
# dataset/CamVid
# Beginning with cropped images
# Preparing model
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# SWAG training
# /content/BayesSegmentation/experiments/segmentation/utils/training.py:27: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
#   nn.init.kaiming_uniform(m.weight)
# ...
